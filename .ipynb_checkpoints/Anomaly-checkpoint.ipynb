# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers

# %%
df = pd.read_csv("mofxdb_fusion_ready.csv")
feature_columns = [
    'surface_area_m2cm3', 'pld', 'lcd', 'num_atoms', 'volume',
    'avg_atomic_mass', 'std_atomic_mass', 'avg_electronegativity',
    'std_electronegativity', 'max_atomic_number', 'metal_fraction',
    'framework_mass'
]
label_columns = ['surface_area_m2g', 'void_fraction', 'density']

# %%
#df_filtered= df[feature_columns]
#lower_bound = df_filtered.quantile(0.03)
#upper_bound = df_filtered.quantile(0.97)
#df_filtered = df_filtered[(df_filtered >= lower_bound).all(axis=1)]
#df_filtered = df_filtered[(df_filtered <= upper_bound).all(axis=1)]

# %%
# ii=0
# for i in feature_columns:
#     if df_filtered[df_filtered[i]==0].shape[0]==0:
#         ax,fig=plt.subplots()
#         sns.histplot(data=df_filtered, x=i, kde=True)

# %%
X = df[feature_columns]

#X = df[feature_columns]
#y = df[label_columns]


scaler_X = StandardScaler()
scaler_X.fit(X)
X_scaled=scaler_X.transform(X)

# %%
X_train_val, X_test = train_test_split(X_scaled, test_size=0.1, random_state=42)
X_train, X_val = train_test_split(X_train_val, test_size=0.11, random_state=42)

input_dim = X_scaled.shape[1]


input_layer = Input(shape=(input_dim,))
encoded = Dense(8, activation='relu')(input_layer)
#encoded = Dense(4, activation='relu')(encoded)

encoded = Dense(4, activation='relu')(encoded)

#decoded = Dense(4, activation='relu')(encoded)
decoded = Dense(8, activation='relu')(encoded)
output_layer = Dense(input_dim, activation='linear')(decoded)

autoencoder = Model(inputs=input_layer, outputs=output_layer)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()

early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5, # Number of epochs to wait for improvement
                               restore_best_weights=True) # Restores the best model weights

history = autoencoder.fit(X_train, X_train,
                          epochs=100,
                          batch_size=32,
                          shuffle=True,
                          validation_data=(X_val, X_val), # This is where the validation set is used!
                          callbacks=[early_stopping],
                          verbose=1)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_9 (InputLayer)        [(None, 12)]              0
#
#  dense_34 (Dense)            (None, 8)                 104
#
#  dense_35 (Dense)            (None, 4)                 36
#
#  dense_36 (Dense)            (None, 8)                 40
#
#  dense_37 (Dense)            (None, 12)                108
#
# ...
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.5274 - val_loss: 0.3264
# Epoch 2/100
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.2647 - val_loss: 0.1976
# Epoch 3/100
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.1641 - val_loss: 0.1379
# Epoch 4/100
# ...

# %%
reconstructions = autoencoder.predict(X_scaled)
errors = np.mean(np.abs(X_scaled - reconstructions), axis=1)
X['anomaly_score'] = errors
# Out:
# 1267/1267 [==============================] - 1s 996us/step
# C:\Users\KaraPardazesh\AppData\Local\Temp\ipykernel_31620\2917735601.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['anomaly_score'] = errors

# %%
for i in range(12):
    fig,ax=plt.subplots()
    ax.set_title(f'{df.columns[i+1]}')
    plt.scatter(X_scaled[:,i],reconstructions[:,i],alpha=0.1,s=20)

# %%
test_reconstructions = autoencoder.predict(X_test)
test_loss = np.mean(np.abs(X_test - test_reconstructions), axis=1)

# Create a DataFrame for easy analysis of the test results
test_results_df = pd.DataFrame({
    'reconstruction_error': test_loss
})

print("\n--- Model Evaluation on Test Set ---")
print(test_results_df['reconstruction_error'].describe())
# Out:
# 127/127 [==============================] - 0s 926us/step
#
# --- Model Evaluation on Test Set ---
# count    4053.000000
# mean        0.203899
# std         0.129121
# min         0.027033
# 25%         0.119755
# 50%         0.175198
# 75%         0.245197
# max         1.165552
# Name: reconstruction_error, dtype: float64

# %%
df_sorted = X.sort_values(by='anomaly_score', ascending=False)

print("\nTop 10 Anomalies:")
print(df_sorted.head(10))
# Out:
# Top 10 Anomalies:
#        surface_area_m2cm3       pld       lcd  num_atoms        volume  \
# 19010             831.129   3.31361   8.78331       4928  1.277505e+05
# 19350            1385.190   4.29732   7.52525        132  3.253173e+03
# 22366             283.587   2.44078   4.66548        244  4.495768e+03
# 26584             305.000  48.70000  79.10000       4144  1.778107e+06
# 38493            1514.070   3.52276   5.84999         20  6.094044e+02
# 26585             314.000  47.50000  78.90000       4144  1.768664e+06
# 23423            1054.920   2.81722   5.32216         80  2.281305e+03
# 23422            1025.170   2.78641   5.26218         80  2.273775e+03
# 23421             973.829   2.73304   5.18289         80  2.246701e+03
# 23420             940.402   2.69825   5.13053         80  2.231452e+03
#
#        avg_atomic_mass  std_atomic_mass  avg_electronegativity  \
# 19010        52.162233        43.381864               2.273333
# ...

# %%
plt.plot(range(X.shape[0]),(df_sorted['anomaly_score']))
plt.xlabel('sorted MOF ID')
plt.ylabel('anomly')
# Out:
# Text(0, 0.5, 'anomly')

# %%
X['anomaly_score'].to_csv('anomaly.csv')
print('DONE')
# Out:
# DONE

# %%
X.shape
# Out:
# (40529, 13)
