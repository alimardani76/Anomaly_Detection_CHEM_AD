# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.decomposition import PCA
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
from sklearn.decomposition import PCA
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Add, Activation
from tensorflow.keras.regularizers import l2
from scipy.spatial import ConvexHull
from matplotlib.path import Path
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers

import os
import random
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.initializers import GlorotUniform
from sklearn.neighbors import LocalOutlierFactor
from tensorflow.keras.layers import Input, Dense, Activation, Add, BatchNormalization, LeakyReLU
from scipy.spatial.distance import mahalanobis
import matplotlib.patheffects as pe
from matplotlib.lines import Line2D
from adjustText import adjust_text

# %%
df= pd.read_csv("dataset.csv",index_col=0)
df = df[df['MOF_ID'] != 'hMOF-1002818']

# %%
metals=['chem_metal_Sc', 'chem_metal_Ti',
       'chem_metal_V', 'chem_metal_Cr', 'chem_metal_Mn', 'chem_metal_Fe',
       'chem_metal_Co', 'chem_metal_Ni', 'chem_metal_Cu', 'chem_metal_Zn',
       'chem_metal_Y', 'chem_metal_Zr', 'chem_metal_Nb', 'chem_metal_Mo',
       'chem_metal_Tc', 'chem_metal_Ru', 'chem_metal_Rh', 'chem_metal_Pd',
       'chem_metal_Ag', 'chem_metal_Cd', 'chem_metal_Hf', 'chem_metal_Ta',
       'chem_metal_W', 'chem_metal_Re', 'chem_metal_Os', 'chem_metal_Ir',
       'chem_metal_Pt', 'chem_metal_Au', 'chem_metal_Hg', 'chem_metal_Al',
       'chem_metal_Ga', 'chem_metal_In', 'chem_metal_Sn', 'chem_metal_Pb',
       'chem_metal_Bi', 'chem_metal_La', 'chem_metal_Ce', 'chem_metal_Pr',
       'chem_metal_Nd', 'chem_metal_Sm', 'chem_metal_Eu', 'chem_metal_Gd',
       'chem_metal_Tb', 'chem_metal_Dy', 'chem_metal_Ho', 'chem_metal_Er',
       'chem_metal_Tm', 'chem_metal_Yb', 'chem_metal_Lu',]
nonmetals=['chem_num_atoms',
 'chem_volume',
 'chem_density',
 'chem_avg_atomic_mass',
 'chem_avg_electronegativity',
 'chem_electronegativity_variance',
 'chem_metal_fraction',
 'chem_num_unique_elements',
 'chem_metal_atom_count',
 'chem_volume_per_atom',
 'geo_surface_area_m2g',
 'geo_surface_area_m2cm3',
 'geo_void_fraction',
 'geo_pld',
 'geo_lcd',
 'link_linker_atom_fraction',
 'link_linker_bond_length_mean',
 'link_linker_bond_length_std',
 'link_metal_coord_number_mean',
 'topo_avg_node_connectivity',
 'topo_avg_ring_size',
 'topo_coordination_number_mean',
 'topo_degree_assortativity',
 'topo_degree_centrality_mean',
 'topo_graph_density',
 'topo_graph_entropy',
 'topo_graph_transitivity',
 'topo_largest_cc_fraction',
 'topo_node_connectivity_std',
 'topo_num_connected_components',
 'topo_num_edges',
 'topo_num_nodes']
features=nonmetals+metals

# %%
df_cleaned = df.dropna()
df_cleaned = df_cleaned.reset_index()
print("NaNs in X_scaled:", df_cleaned.isnull().sum().sum())
# Out:
# NaNs in X_scaled: 0

# %%
output_dir='jaccard for chemical features/'

# %%
m=3.5

params = {
    # Font family
    'font.family': 'sans-serif',
    'font.sans-serif': ['Arial'],

    # Font sizes
    "axes.labelsize": 10*m,
    "font.size": 10*m,
    "legend.fontsize": 10*m,
    "xtick.labelsize": 9*m,
    "ytick.labelsize": 9*m,

    # Style for axis labels (xlabel, ylabel)
    'axes.labelweight': 'bold',
    'axes.labelcolor': 'black',

    # General styles for other elements
    'font.weight': 'bold',       # Makes title, etc., bold
    'xtick.color': 'black',      # Sets tick label color
    'ytick.color': 'black',
    'legend.labelcolor': 'black'
}

plt.rcParams.update(params)

# %%
latent_dim=16
step_size=2
bs=32*100
lr=0.001
rs=0
for condition in ['no metals', 'with metals']:
    if condition=='no metals':
        X_train_val_full, X_test_full = train_test_split(df_cleaned, test_size=0.2, random_state=rs)
        X_train_full, X_val_full = train_test_split(X_train_val_full, test_size=0.25, random_state=42)
        
        scaler_X = StandardScaler()
        scaler_X.fit(X_train_full[nonmetals])
        
        X_train = scaler_X.transform(X_train_full[nonmetals])
        X_train = pd.DataFrame(X_train, index=X_train_full.index, columns=nonmetals)
        
        X_val = scaler_X.transform(X_val_full[nonmetals])
        X_val = pd.DataFrame(X_val, index=X_val_full.index, columns=nonmetals)
        
        X_test = scaler_X.transform(X_test_full[nonmetals])
        X_test = pd.DataFrame(X_test, index=X_test_full.index, columns=nonmetals)
        
        X_full_dataset=pd.concat([X_train, X_val,X_test], axis=0)



        
    else:
        X_train_val_full, X_test_full = train_test_split(df_cleaned, test_size=0.2, random_state=rs)
        X_train_full, X_val_full = train_test_split(X_train_val_full, test_size=0.25, random_state=42)
        
        scaler_X = StandardScaler()
        scaler_X.fit(X_train_full[nonmetals])
        
        X_train_nonmetal_np = scaler_X.transform(X_train_full[nonmetals])
        X_train_nonmetal = pd.DataFrame(X_train_nonmetal_np, index=X_train_full.index, columns=nonmetals)
        X_train = pd.concat([X_train_nonmetal, X_train_full[metals]], axis=1)
        
        X_val_nonmetal_np = scaler_X.transform(X_val_full[nonmetals])
        X_val_nonmetal = pd.DataFrame(X_val_nonmetal_np, index=X_val_full.index, columns=nonmetals)
        X_val = pd.concat([X_val_nonmetal, X_val_full[metals]], axis=1)
        
        X_test_nonmetal_np = scaler_X.transform(X_test_full[nonmetals])
        X_test_nonmetal = pd.DataFrame(X_test_nonmetal_np, index=X_test_full.index, columns=nonmetals)
        X_test = pd.concat([X_test_nonmetal, X_test_full[metals]], axis=1)
        
        X_full_dataset=pd.concat([X_train, X_val,X_test], axis=0)
        

    print(f"\n===== Training Model: Latent Dim = {latent_dim}, Step Size = {step_size} =====\n")
    input_dim=X_train.shape[1]
    encoder_neurons = list(range(input_dim - step_size, latent_dim, -step_size))
    decoder_neurons = encoder_neurons[::-1]
    
    input_layer = Input(shape=(input_dim,))
    x = input_layer
    
    for neurons in encoder_neurons:
        x = Dense(neurons)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
    
    encoded = Dense(latent_dim, name='latent_space')(x)
    x = encoded
    
    for neurons in decoder_neurons:
        x = Dense(neurons)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
    
    output_layer = Dense(input_dim, activation='linear')(x)
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    
    optimizer = Adam(learning_rate=lr)
    autoencoder.compile(optimizer=optimizer, loss='mse')
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True, verbose=0)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-5, verbose=0)
    
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, X_train)).batch(bs).prefetch(tf.data.AUTOTUNE)
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, X_val)).batch(bs).prefetch(tf.data.AUTOTUNE)
    
    history = autoencoder.fit(
        train_ds,
        epochs=200,
        validation_data=val_ds,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    pd.DataFrame(history.history).to_csv(f'{output_dir}/hist/loss_{latent_dim}_{step_size}_{condition}.csv')
    
    reconstructions_train = autoencoder.predict(X_train.values)
    reconstructions_test = autoencoder.predict(X_test.values)
    reconstructions_full = autoencoder.predict(X_full_dataset.values)
    
    errors_train = np.mean(np.square(X_train.values - reconstructions_train), axis=1)
    np.save(f'jaccard for chemical features/errors_train_{condition}.npy',errors_train)
# Out:
# ===== Training Model: Latent Dim = 16, Step Size = 2 =====
#
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 312ms/step - loss: 1.5039 - val_loss: 0.9897 - learning_rate: 0.0010
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.3339 - val_loss: 0.9897 - learning_rate: 0.0010
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.2264 - val_loss: 0.9898 - learning_rate: 0.0010
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.1498 - val_loss: 0.9899 - learning_rate: 0.0010
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.0898 - val_loss: 0.9901 - learning_rate: 0.0010
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.0434 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.0060 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.9765 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9503 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.9262 - val_loss: 0.9901 - learning_rate: 0.0010
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.9038 - val_loss: 0.9899 - learning_rate: 0.0010
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.8875 - val_loss: 0.9897 - learning_rate: 2.0000e-04
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.8824 - val_loss: 0.9894 - learning_rate: 2.0000e-04
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8772 - val_loss: 0.9891 - learning_rate: 2.0000e-04
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8718 - val_loss: 0.9886 - learning_rate: 2.0000e-04
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.8664 - val_loss: 0.9881 - learning_rate: 2.0000e-04
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.8610 - val_loss: 0.9873 - learning_rate: 2.0000e-04
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8555 - val_loss: 0.9865 - learning_rate: 2.0000e-04
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8500 - val_loss: 0.9856 - learning_rate: 2.0000e-04
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8446 - val_loss: 0.9844 - learning_rate: 2.0000e-04
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8391 - val_loss: 0.9830 - learning_rate: 2.0000e-04
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8336 - val_loss: 0.9813 - learning_rate: 2.0000e-04
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8282 - val_loss: 0.9794 - learning_rate: 2.0000e-04
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.8228 - val_loss: 0.9773 - learning_rate: 2.0000e-04
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8175 - val_loss: 0.9748 - learning_rate: 2.0000e-04
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8122 - val_loss: 0.9721 - learning_rate: 2.0000e-04
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8069 - val_loss: 0.9691 - learning_rate: 2.0000e-04
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8015 - val_loss: 0.9660 - learning_rate: 2.0000e-04
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.7962 - val_loss: 0.9625 - learning_rate: 2.0000e-04
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.7909 - val_loss: 0.9588 - learning_rate: 2.0000e-04
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.7856 - val_loss: 0.9549 - learning_rate: 2.0000e-04
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.7802 - val_loss: 0.9505 - learning_rate: 2.0000e-04
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7749 - val_loss: 0.9459 - learning_rate: 2.0000e-04
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7695 - val_loss: 0.9410 - learning_rate: 2.0000e-04
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.7642 - val_loss: 0.9358 - learning_rate: 2.0000e-04
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.7589 - val_loss: 0.9302 - learning_rate: 2.0000e-04
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.7534 - val_loss: 0.9241 - learning_rate: 2.0000e-04
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.7480 - val_loss: 0.9177 - learning_rate: 2.0000e-04
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.7423 - val_loss: 0.9110 - learning_rate: 2.0000e-04
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.7367 - val_loss: 0.9039 - learning_rate: 2.0000e-04
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7311 - val_loss: 0.8967 - learning_rate: 2.0000e-04
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.7256 - val_loss: 0.8893 - learning_rate: 2.0000e-04
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7203 - val_loss: 0.8818 - learning_rate: 2.0000e-04
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7149 - val_loss: 0.8741 - learning_rate: 2.0000e-04
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.7096 - val_loss: 0.8662 - learning_rate: 2.0000e-04
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7045 - val_loss: 0.8581 - learning_rate: 2.0000e-04
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6993 - val_loss: 0.8498 - learning_rate: 2.0000e-04
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.6942 - val_loss: 0.8416 - learning_rate: 2.0000e-04
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.6890 - val_loss: 0.8331 - learning_rate: 2.0000e-04
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6841 - val_loss: 0.8245 - learning_rate: 2.0000e-04
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.6791 - val_loss: 0.8159 - learning_rate: 2.0000e-04
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6743 - val_loss: 0.8072 - learning_rate: 2.0000e-04
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6696 - val_loss: 0.7984 - learning_rate: 2.0000e-04
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6647 - val_loss: 0.7892 - learning_rate: 2.0000e-04
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.6600 - val_loss: 0.7800 - learning_rate: 2.0000e-04
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6552 - val_loss: 0.7708 - learning_rate: 2.0000e-04
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6507 - val_loss: 0.7613 - learning_rate: 2.0000e-04
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.6461 - val_loss: 0.7520 - learning_rate: 2.0000e-04
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.6417 - val_loss: 0.7432 - learning_rate: 2.0000e-04
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.6375 - val_loss: 0.7347 - learning_rate: 2.0000e-04
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6332 - val_loss: 0.7263 - learning_rate: 2.0000e-04
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6292 - val_loss: 0.7184 - learning_rate: 2.0000e-04
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6252 - val_loss: 0.7103 - learning_rate: 2.0000e-04
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.6212 - val_loss: 0.7020 - learning_rate: 2.0000e-04
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6172 - val_loss: 0.6941 - learning_rate: 2.0000e-04
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.6134 - val_loss: 0.6867 - learning_rate: 2.0000e-04
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.6096 - val_loss: 0.6794 - learning_rate: 2.0000e-04
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6058 - val_loss: 0.6724 - learning_rate: 2.0000e-04
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.6023 - val_loss: 0.6656 - learning_rate: 2.0000e-04
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.5987 - val_loss: 0.6590 - learning_rate: 2.0000e-04
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.5952 - val_loss: 0.6526 - learning_rate: 2.0000e-04
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5919 - val_loss: 0.6465 - learning_rate: 2.0000e-04
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5885 - val_loss: 0.6408 - learning_rate: 2.0000e-04
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5853 - val_loss: 0.6355 - learning_rate: 2.0000e-04
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5821 - val_loss: 0.6302 - learning_rate: 2.0000e-04
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.5790 - val_loss: 0.6253 - learning_rate: 2.0000e-04
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5759 - val_loss: 0.6204 - learning_rate: 2.0000e-04
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5729 - val_loss: 0.6157 - learning_rate: 2.0000e-04
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5699 - val_loss: 0.6113 - learning_rate: 2.0000e-04
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5670 - val_loss: 0.6069 - learning_rate: 2.0000e-04
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5641 - val_loss: 0.6022 - learning_rate: 2.0000e-04
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5613 - val_loss: 0.5977 - learning_rate: 2.0000e-04
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5585 - val_loss: 0.5937 - learning_rate: 2.0000e-04
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.5559 - val_loss: 0.5894 - learning_rate: 2.0000e-04
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5532 - val_loss: 0.5853 - learning_rate: 2.0000e-04
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5506 - val_loss: 0.5815 - learning_rate: 2.0000e-04
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5481 - val_loss: 0.5777 - learning_rate: 2.0000e-04
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5456 - val_loss: 0.5742 - learning_rate: 2.0000e-04
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5432 - val_loss: 0.5708 - learning_rate: 2.0000e-04
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5408 - val_loss: 0.5674 - learning_rate: 2.0000e-04
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5385 - val_loss: 0.5642 - learning_rate: 2.0000e-04
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5361 - val_loss: 0.5607 - learning_rate: 2.0000e-04
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5338 - val_loss: 0.5571 - learning_rate: 2.0000e-04
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5314 - val_loss: 0.5540 - learning_rate: 2.0000e-04
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5291 - val_loss: 0.5512 - learning_rate: 2.0000e-04
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5269 - val_loss: 0.5485 - learning_rate: 2.0000e-04
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5247 - val_loss: 0.5458 - learning_rate: 2.0000e-04
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5226 - val_loss: 0.5433 - learning_rate: 2.0000e-04
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5204 - val_loss: 0.5407 - learning_rate: 2.0000e-04
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.5184 - val_loss: 0.5384 - learning_rate: 2.0000e-04
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.5164 - val_loss: 0.5361 - learning_rate: 2.0000e-04
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5144 - val_loss: 0.5337 - learning_rate: 2.0000e-04
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5125 - val_loss: 0.5317 - learning_rate: 2.0000e-04
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5106 - val_loss: 0.5298 - learning_rate: 2.0000e-04
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5087 - val_loss: 0.5277 - learning_rate: 2.0000e-04
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5069 - val_loss: 0.5258 - learning_rate: 2.0000e-04
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5051 - val_loss: 0.5239 - learning_rate: 2.0000e-04
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.5033 - val_loss: 0.5219 - learning_rate: 2.0000e-04
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.5016 - val_loss: 0.5200 - learning_rate: 2.0000e-04
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4999 - val_loss: 0.5183 - learning_rate: 2.0000e-04
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4982 - val_loss: 0.5165 - learning_rate: 2.0000e-04
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4966 - val_loss: 0.5148 - learning_rate: 2.0000e-04
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4949 - val_loss: 0.5133 - learning_rate: 2.0000e-04
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4933 - val_loss: 0.5117 - learning_rate: 2.0000e-04
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4917 - val_loss: 0.5101 - learning_rate: 2.0000e-04
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4901 - val_loss: 0.5086 - learning_rate: 2.0000e-04
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4886 - val_loss: 0.5071 - learning_rate: 2.0000e-04
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4870 - val_loss: 0.5055 - learning_rate: 2.0000e-04
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4855 - val_loss: 0.5039 - learning_rate: 2.0000e-04
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4840 - val_loss: 0.5024 - learning_rate: 2.0000e-04
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4825 - val_loss: 0.5010 - learning_rate: 2.0000e-04
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4810 - val_loss: 0.4996 - learning_rate: 2.0000e-04
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4795 - val_loss: 0.4982 - learning_rate: 2.0000e-04
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4780 - val_loss: 0.4967 - learning_rate: 2.0000e-04
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4766 - val_loss: 0.4954 - learning_rate: 2.0000e-04
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4752 - val_loss: 0.4941 - learning_rate: 2.0000e-04
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4737 - val_loss: 0.4929 - learning_rate: 2.0000e-04
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4723 - val_loss: 0.4917 - learning_rate: 2.0000e-04
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4709 - val_loss: 0.4905 - learning_rate: 2.0000e-04
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4695 - val_loss: 0.4891 - learning_rate: 2.0000e-04
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4682 - val_loss: 0.4878 - learning_rate: 2.0000e-04
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4668 - val_loss: 0.4865 - learning_rate: 2.0000e-04
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4654 - val_loss: 0.4853 - learning_rate: 2.0000e-04
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4641 - val_loss: 0.4842 - learning_rate: 2.0000e-04
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4628 - val_loss: 0.4828 - learning_rate: 2.0000e-04
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4614 - val_loss: 0.4815 - learning_rate: 2.0000e-04
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4602 - val_loss: 0.4803 - learning_rate: 2.0000e-04
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4589 - val_loss: 0.4792 - learning_rate: 2.0000e-04
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4576 - val_loss: 0.4781 - learning_rate: 2.0000e-04
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4564 - val_loss: 0.4770 - learning_rate: 2.0000e-04
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4551 - val_loss: 0.4758 - learning_rate: 2.0000e-04
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4539 - val_loss: 0.4747 - learning_rate: 2.0000e-04
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4527 - val_loss: 0.4739 - learning_rate: 2.0000e-04
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4515 - val_loss: 0.4727 - learning_rate: 2.0000e-04
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4503 - val_loss: 0.4715 - learning_rate: 2.0000e-04
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4492 - val_loss: 0.4704 - learning_rate: 2.0000e-04
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4480 - val_loss: 0.4694 - learning_rate: 2.0000e-04
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4468 - val_loss: 0.4682 - learning_rate: 2.0000e-04
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4456 - val_loss: 0.4671 - learning_rate: 2.0000e-04
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.4445 - val_loss: 0.4660 - learning_rate: 2.0000e-04
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4434 - val_loss: 0.4649 - learning_rate: 2.0000e-04
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4422 - val_loss: 0.4638 - learning_rate: 2.0000e-04
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4411 - val_loss: 0.4628 - learning_rate: 2.0000e-04
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4400 - val_loss: 0.4617 - learning_rate: 2.0000e-04
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4389 - val_loss: 0.4606 - learning_rate: 2.0000e-04
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4378 - val_loss: 0.4597 - learning_rate: 2.0000e-04
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4367 - val_loss: 0.4587 - learning_rate: 2.0000e-04
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4357 - val_loss: 0.4576 - learning_rate: 2.0000e-04
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4346 - val_loss: 0.4566 - learning_rate: 2.0000e-04
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4336 - val_loss: 0.4557 - learning_rate: 2.0000e-04
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4326 - val_loss: 0.4547 - learning_rate: 2.0000e-04
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4316 - val_loss: 0.4538 - learning_rate: 2.0000e-04
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4306 - val_loss: 0.4529 - learning_rate: 2.0000e-04
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4296 - val_loss: 0.4521 - learning_rate: 2.0000e-04
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4286 - val_loss: 0.4511 - learning_rate: 2.0000e-04
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4276 - val_loss: 0.4502 - learning_rate: 2.0000e-04
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4267 - val_loss: 0.4493 - learning_rate: 2.0000e-04
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4257 - val_loss: 0.4485 - learning_rate: 2.0000e-04
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4248 - val_loss: 0.4475 - learning_rate: 2.0000e-04
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4238 - val_loss: 0.4465 - learning_rate: 2.0000e-04
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4229 - val_loss: 0.4456 - learning_rate: 2.0000e-04
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4220 - val_loss: 0.4448 - learning_rate: 2.0000e-04
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4210 - val_loss: 0.4439 - learning_rate: 2.0000e-04
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4201 - val_loss: 0.4431 - learning_rate: 2.0000e-04
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4192 - val_loss: 0.4423 - learning_rate: 2.0000e-04
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4183 - val_loss: 0.4414 - learning_rate: 2.0000e-04
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4174 - val_loss: 0.4406 - learning_rate: 2.0000e-04
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4165 - val_loss: 0.4398 - learning_rate: 2.0000e-04
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4156 - val_loss: 0.4391 - learning_rate: 2.0000e-04
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4147 - val_loss: 0.4383 - learning_rate: 2.0000e-04
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.4139 - val_loss: 0.4374 - learning_rate: 2.0000e-04
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4130 - val_loss: 0.4368 - learning_rate: 2.0000e-04
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4121 - val_loss: 0.4360 - learning_rate: 2.0000e-04
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4112 - val_loss: 0.4353 - learning_rate: 2.0000e-04
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.4104 - val_loss: 0.4344 - learning_rate: 2.0000e-04
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4096 - val_loss: 0.4338 - learning_rate: 2.0000e-04
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4087 - val_loss: 0.4330 - learning_rate: 2.0000e-04
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4079 - val_loss: 0.4323 - learning_rate: 2.0000e-04
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4070 - val_loss: 0.4315 - learning_rate: 2.0000e-04
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.4062 - val_loss: 0.4308 - learning_rate: 2.0000e-04
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4054 - val_loss: 0.4300 - learning_rate: 2.0000e-04
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4046 - val_loss: 0.4294 - learning_rate: 2.0000e-04
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4038 - val_loss: 0.4287 - learning_rate: 2.0000e-04
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4030 - val_loss: 0.4279 - learning_rate: 2.0000e-04
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4022 - val_loss: 0.4273 - learning_rate: 2.0000e-04
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4014 - val_loss: 0.4265 - learning_rate: 2.0000e-04
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.4005 - val_loss: 0.4258 - learning_rate: 2.0000e-04
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3997 - val_loss: 0.4251 - learning_rate: 2.0000e-04
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3989 - val_loss: 0.4245 - learning_rate: 2.0000e-04
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3981 - val_loss: 0.4238 - learning_rate: 2.0000e-04
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#
# ===== Training Model: Latent Dim = 16, Step Size = 2 =====
#
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.7813 - val_loss: 0.4038 - learning_rate: 0.0010
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - loss: 0.6047 - val_loss: 0.4037 - learning_rate: 0.0010
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - loss: 0.5230 - val_loss: 0.4037 - learning_rate: 0.0010
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - loss: 0.4799 - val_loss: 0.4037 - learning_rate: 0.0010
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - loss: 0.4537 - val_loss: 0.4036 - learning_rate: 0.0010
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - loss: 0.4360 - val_loss: 0.4035 - learning_rate: 0.0010
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - loss: 0.4265 - val_loss: 0.4034 - learning_rate: 0.0010
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - loss: 0.4189 - val_loss: 0.4032 - learning_rate: 0.0010
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - loss: 0.4145 - val_loss: 0.4030 - learning_rate: 0.0010
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - loss: 0.4105 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 357ms/step - loss: 0.4089 - val_loss: 0.4027 - learning_rate: 0.0010
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - loss: 0.4070 - val_loss: 0.4025 - learning_rate: 0.0010
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - loss: 0.4047 - val_loss: 0.4023 - learning_rate: 0.0010
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 310ms/step - loss: 0.4032 - val_loss: 0.4021 - learning_rate: 0.0010
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - loss: 0.4020 - val_loss: 0.4019 - learning_rate: 0.0010
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - loss: 0.4025 - val_loss: 0.4018 - learning_rate: 0.0010
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - loss: 0.4015 - val_loss: 0.4016 - learning_rate: 0.0010
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - loss: 0.4006 - val_loss: 0.4015 - learning_rate: 0.0010
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 329ms/step - loss: 0.3998 - val_loss: 0.4015 - learning_rate: 0.0010
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - loss: 0.4013 - val_loss: 0.4014 - learning_rate: 0.0010
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.4010 - val_loss: 0.4014 - learning_rate: 0.0010
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - loss: 0.4012 - val_loss: 0.4013 - learning_rate: 0.0010
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - loss: 0.4008 - val_loss: 0.4013 - learning_rate: 0.0010
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 310ms/step - loss: 0.4004 - val_loss: 0.4013 - learning_rate: 0.0010
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - loss: 0.4013 - val_loss: 0.4012 - learning_rate: 0.0010
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - loss: 0.4013 - val_loss: 0.4012 - learning_rate: 0.0010
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.4004 - val_loss: 0.4012 - learning_rate: 0.0010
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - loss: 0.4006 - val_loss: 0.4011 - learning_rate: 0.0010
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - loss: 0.3992 - val_loss: 0.4011 - learning_rate: 0.0010
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - loss: 0.3998 - val_loss: 0.4011 - learning_rate: 0.0010
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.3982 - val_loss: 0.4011 - learning_rate: 0.0010
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - loss: 0.3995 - val_loss: 0.4011 - learning_rate: 0.0010
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - loss: 0.3994 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - loss: 0.3985 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - loss: 0.3970 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 329ms/step - loss: 0.3952 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.3946 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.3931 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - loss: 0.3945 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - loss: 0.3935 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - loss: 0.3940 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.3938 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - loss: 0.3938 - val_loss: 0.4010 - learning_rate: 0.0010
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - loss: 0.3927 - val_loss: 0.4010 - learning_rate: 2.0000e-04
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - loss: 0.3914 - val_loss: 0.4010 - learning_rate: 2.0000e-04
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - loss: 0.3901 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - loss: 0.3889 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - loss: 0.3880 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - loss: 0.3881 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - loss: 0.3874 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - loss: 0.3870 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.3868 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - loss: 0.3861 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 330ms/step - loss: 0.3858 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.3854 - val_loss: 0.4009 - learning_rate: 2.0000e-04
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.3848 - val_loss: 0.4008 - learning_rate: 2.0000e-04
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - loss: 0.3848 - val_loss: 0.4008 - learning_rate: 2.0000e-04
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.3844 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - loss: 0.3843 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.3841 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - loss: 0.3836 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - loss: 0.3832 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - loss: 0.3830 - val_loss: 0.4008 - learning_rate: 4.0000e-05
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.3827 - val_loss: 0.4007 - learning_rate: 4.0000e-05
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - loss: 0.3825 - val_loss: 0.4007 - learning_rate: 4.0000e-05
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 304ms/step - loss: 0.3825 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.3828 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - loss: 0.3823 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - loss: 0.3823 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - loss: 0.3821 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - loss: 0.3819 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - loss: 0.3818 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - loss: 0.3817 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - loss: 0.3816 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step - loss: 0.3814 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - loss: 0.3814 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - loss: 0.3814 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - loss: 0.3813 - val_loss: 0.4005 - learning_rate: 4.0000e-05
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - loss: 0.3813 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - loss: 0.3811 - val_loss: 0.4006 - learning_rate: 4.0000e-05
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - loss: 0.3810 - val_loss: 0.4005 - learning_rate: 1.0000e-05
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.3809 - val_loss: 0.4001 - learning_rate: 1.0000e-05
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - loss: 0.3807 - val_loss: 0.4006 - learning_rate: 1.0000e-05
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 304ms/step - loss: 0.3807 - val_loss: 0.3997 - learning_rate: 1.0000e-05
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - loss: 0.3806 - val_loss: 0.3999 - learning_rate: 1.0000e-05
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.3806 - val_loss: 0.3999 - learning_rate: 1.0000e-05
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - loss: 0.3805 - val_loss: 0.3981 - learning_rate: 1.0000e-05
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.3805 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - loss: 0.3804 - val_loss: 0.3986 - learning_rate: 1.0000e-05
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - loss: 0.3803 - val_loss: 0.3989 - learning_rate: 1.0000e-05
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.3803 - val_loss: 0.3984 - learning_rate: 1.0000e-05
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - loss: 0.3803 - val_loss: 0.3977 - learning_rate: 1.0000e-05
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - loss: 0.3802 - val_loss: 0.3978 - learning_rate: 1.0000e-05
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - loss: 0.3802 - val_loss: 0.3982 - learning_rate: 1.0000e-05
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - loss: 0.3801 - val_loss: 0.3988 - learning_rate: 1.0000e-05
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - loss: 0.3801 - val_loss: 0.3983 - learning_rate: 1.0000e-05
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - loss: 0.3801 - val_loss: 0.3979 - learning_rate: 1.0000e-05
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - loss: 0.3800 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - loss: 0.3800 - val_loss: 0.4007 - learning_rate: 1.0000e-05
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - loss: 0.3800 - val_loss: 0.4007 - learning_rate: 1.0000e-05
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - loss: 0.3799 - val_loss: 0.3997 - learning_rate: 1.0000e-05
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - loss: 0.3799 - val_loss: 0.3986 - learning_rate: 1.0000e-05
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - loss: 0.3799 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - loss: 0.3798 - val_loss: 0.3980 - learning_rate: 1.0000e-05
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.3798 - val_loss: 0.3976 - learning_rate: 1.0000e-05
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - loss: 0.3798 - val_loss: 0.3969 - learning_rate: 1.0000e-05
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - loss: 0.3797 - val_loss: 0.3966 - learning_rate: 1.0000e-05
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - loss: 0.3797 - val_loss: 0.3973 - learning_rate: 1.0000e-05
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - loss: 0.3797 - val_loss: 0.3979 - learning_rate: 1.0000e-05
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - loss: 0.3797 - val_loss: 0.3982 - learning_rate: 1.0000e-05
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - loss: 0.3797 - val_loss: 0.3986 - learning_rate: 1.0000e-05
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - loss: 0.3797 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - loss: 0.3796 - val_loss: 0.3988 - learning_rate: 1.0000e-05
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - loss: 0.3796 - val_loss: 0.3992 - learning_rate: 1.0000e-05
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - loss: 0.3796 - val_loss: 0.4002 - learning_rate: 1.0000e-05
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - loss: 0.3795 - val_loss: 0.4015 - learning_rate: 1.0000e-05
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.3795 - val_loss: 0.4027 - learning_rate: 1.0000e-05
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.3795 - val_loss: 0.4034 - learning_rate: 1.0000e-05
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - loss: 0.3795 - val_loss: 0.4042 - learning_rate: 1.0000e-05
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - loss: 0.3795 - val_loss: 0.4053 - learning_rate: 1.0000e-05
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.3794 - val_loss: 0.4062 - learning_rate: 1.0000e-05
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - loss: 0.3794 - val_loss: 0.4067 - learning_rate: 1.0000e-05
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 310ms/step - loss: 0.3794 - val_loss: 0.4071 - learning_rate: 1.0000e-05
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 0.3794 - val_loss: 0.4075 - learning_rate: 1.0000e-05
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - loss: 0.3793 - val_loss: 0.4068 - learning_rate: 1.0000e-05
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step - loss: 0.3793 - val_loss: 0.4062 - learning_rate: 1.0000e-05
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - loss: 0.3793 - val_loss: 0.4062 - learning_rate: 1.0000e-05
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - loss: 0.3793 - val_loss: 0.4062 - learning_rate: 1.0000e-05
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - loss: 0.3792 - val_loss: 0.4064 - learning_rate: 1.0000e-05
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - loss: 0.3792 - val_loss: 0.4068 - learning_rate: 1.0000e-05
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - loss: 0.3792 - val_loss: 0.4070 - learning_rate: 1.0000e-05
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - loss: 0.3791 - val_loss: 0.4069 - learning_rate: 1.0000e-05
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step

# %%
list_errors=[]
for x in ['jaccard for chemical features/errors_train_no metals.npy',
         'jaccard for chemical features/errors_train_with metals.npy']:
    list_errors.append(np.load(x))

# %%
K_values = [50, 100, 200]

# Check if we have exactly two lists
if len(list_errors) != 2:
    print(f"Error: list_errors contains {len(list_errors)} items. This script expects exactly 2.")
else:
    # Get the two error lists
    errors_a = np.asarray(list_errors[0])
    errors_b = np.asarray(list_errors[1])

    print("Calculating Jaccard Index for Top-K Anomalies")
    print("---------------------------------------------")

    for k in K_values:
        # 1. Find the indices of the top-K anomalies for each model
        # np.argsort() sorts ascending, so [-k:] gives the indices of the K largest values.
        top_k_indices_a = set(np.argsort(errors_a)[-k:])
        top_k_indices_b = set(np.argsort(errors_b)[-k:])
        
        # 2. Calculate intersection and union
        intersection_count = len(top_k_indices_a.intersection(top_k_indices_b))
        union_count = len(top_k_indices_a.union(top_k_indices_b))
        
        # 3. Calculate Jaccard Index: |A intersect B| / |A union B|
        if union_count == 0:
            jaccard_score = 1.0 if intersection_count == 0 else 0.0
        else:
            jaccard_score = intersection_count / union_count
            
        print(f"K = {k}:")
        print(f"  - Intersection (Overlap): {intersection_count}")
        print(f"  - Union: {union_count}")
        print(f"  - Jaccard Index: {jaccard_score:.4f}\n")
# Out:
# Calculating Jaccard Index for Top-K Anomalies
# ---------------------------------------------
# K = 50:
#   - Intersection (Overlap): 33
#   - Union: 67
#   - Jaccard Index: 0.4925
#
# K = 100:
#   - Intersection (Overlap): 62
#   - Union: 138
#   - Jaccard Index: 0.4493
#
# K = 200:
#   - Intersection (Overlap): 112
#   - Union: 288
#   - Jaccard Index: 0.3889

# %%
from scipy.stats import spearmanr
correlation, p_value = spearmanr(list_errors[0][:], list_errors[1])

print(f"Spearman Rank Correlation (ρ): {correlation:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Spearman Rank Correlation (ρ): 0.5942
# P-value: 0.0000

# %%
errors_A=list_errors[0]
errors_B=list_errors[1]

# %%
df_A=pd.DataFrame(errors_A,columns=['errors']).sort_values(by='errors',ascending=False).iloc[:200]
df_B=pd.DataFrame(errors_B,columns=['errors']).sort_values(by='errors',ascending=False).iloc[:1000]

# %%
inds_A=df_A.index
inds_B=df_B.index

# %%
contain=0
for x in inds_A:
    for y in inds_B:
        if x==y:
            contain=contain+1
print(contain,contain/200*100)
# Out:
# 191 95.5
